# %%
# In this challenge the definition of churn is “no new valid service subscription within 30 days after the current membership expires.”

import csv
import pandas as pd
import os
import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import __version__ as sklearn_version
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.pipeline import make_pipeline

# %%
pd.set_option('display.max_columns', None)

# %%
# Train table contains user ID and whether or not they churned

traindf = pd.read_csv(r"C:\Users\marsh\Desktop\Springboard\Capstone2\train_v2.csv")
traindf
# Out:
#                                                 msno  is_churn
# 0       ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         1
# 1       f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1
# 2       zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1
# 3       8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1
# 4       K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1
# ...                                              ...       ...
# 970955  OHnZbu+EVaP+vN7Z+OfT5OMcp90MWFZonmM0o3pb8FY=         0
# 970956  S92bDK//uI6hk3u1vuApro0qJBQOToBozZ7lL1yTC+w=         0
# 970957  eUa3xo16vpAjr43Cjlb6Kjf1NTILYyJIkBayJQdXWnw=         0
# 970958  iZE41tbAQ65rJq60olkJT4BJzuUAYgQdfbEemXe/TTk=         0
# 970959  oECkzJik4wKsbOEVY6UACLbmgM8qymFdb5cJaHrodY8=         0
#
# [970960 rows x 2 columns]

# %%
traindf.is_churn.value_counts()
# Out:
# 0    883630
# 1     87330
# Name: is_churn, dtype: int64

# %%
traindf.isnull().sum()
# Out:
# msno        0
# is_churn    0
# dtype: int64

# %%
traindf.msno.duplicated().any()
# Out:
# False

# %%
traindf.describe()
# Out:
#             is_churn
# count  970960.000000
# mean        0.089942
# std         0.286099
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
# members table includes a user's personal and registration information

memdf = pd.read_csv(r"C:\Users\marsh\Desktop\Springboard\Capstone2\members_v3.csv")
memdf
# Out:
#                                                  msno  city  bd  gender  \
# 0        Rb9UwLQTrxzBVwCB6+bCcSQWZ9JiNLC9dXtM1oEsZA8=     1   0     NaN
# 1        +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1   0     NaN
# 2        cV358ssn7a0f7jZOwGNWS07wCKVqxyiImJUX6xcIwKw=     1   0     NaN
# 3        9bzDeJP6sQodK73K5CBlJ6fgIQzPeLnRl0p5B77XP+g=     1   0     NaN
# 4        WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=     6  32  female
# ...                                               ...   ...  ..     ...
# 6769468  VSGkb3hyBRUtb/b1MQUZbvOkktS3vKLnhMHW0CF8eyU=     1   0     NaN
# 6769469  nWjH7glPkZ7jOVaCRwwjlpmp0T1hSWdv8hMJxiWCwKc=     1   0     NaN
# 6769470  GH+b5+1tlv7ZZXsA8upBzVXMTLyffKcsF7WoU8b5rOI=    15  26  female
# 6769471  XVlwT3fdCFGKqerEKBzUIjK+jzI6jzSke4cDMVhYyjE=     1   0     NaN
# 6769472  isBt+JlgvZRNy6lxVr5vvuJ4lD00ofTaKyJ+uRnGcPg=     1   0     NaN
#
#          registered_via  registration_init_time
# 0                    11                20110911
# 1                     7                20110914
# 2                    11                20110915
# 3                    11                20110915
# 4                     9                20110915
# ...                 ...                     ...
# 6769468               7                20151020
# 6769469               7                20151020
# 6769470               4                20151020
# 6769471               4                20151020
# 6769472               4                20151021
#
# [6769473 rows x 6 columns]

# %%
memdf.msno.duplicated().any()
# Out:
# False

# %%
# a lot of null values for gender
memdf.isnull().sum()
# Out:
# msno                            0
# city                            0
# bd                              0
# gender                    4429505
# registered_via                  0
# registration_init_time          0
# dtype: int64

# %%
# filter for rows where age is between 10-100 and gender is not null

memdf = memdf[(memdf.bd > 10) & (memdf.bd < 100)]
memdf.dropna(axis = 0, inplace = True)
memdf
# Out:
#                                                  msno  city  bd  gender  \
# 4        WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=     6  32  female
# 5        yLkV2gbZ4GLFwqTOXLVHz0VGrMYcgBGgKZ3kj9RiYu8=     4  30    male
# 7        WH5Jq4mgtfUFXh2yz+HrcTXKS4Oess4k4W3qKolAeb0=     5  34    male
# 8        tKmbR4X5VXjHmxERrckawEMZ4znVy1lAQIR1vV5rdNk=     5  19    male
# 9        I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13  63    male
# ...                                               ...   ...  ..     ...
# 6769455  IwDZCuhB0UP7wrBwuqE1r1jQIA0yFSTqUGlGJnM+hMI=     1  52    male
# 6769462  y0rwiAeU5goDatsiUDulPdiJpohZ15hxUAkSJHccnvY=     8  32  female
# 6769464  2U0grRyv2DB3Pw3crMBhBfsWWq6VkGcK1IGVqmDmK0w=     5  23  female
# 6769467  tyoRqQ72Y2oCcqvdaIxG8T0Hs9DZvuuM8IeTwhxtdBQ=     6  26  female
# 6769470  GH+b5+1tlv7ZZXsA8upBzVXMTLyffKcsF7WoU8b5rOI=    15  26  female
#
#          registered_via  registration_init_time
# 4                     9                20110915
# 5                     9                20110916
# 7                     9                20110916
# 8                     9                20110917
# 9                     9                20110918
# ...                 ...                     ...
# 6769455               4                20151020
# 6769462               9                20151020
# 6769464               4                20151020
# 6769467               7                20151020
# 6769470               4                20151020
#
# [2181930 rows x 6 columns]

# %%
# merge two tables on msno

df1 = traindf.merge(memdf, on = 'msno', how = 'inner')

# %%
# no null values

df1.isna().sum()
# Out:
# msno                      0
# is_churn                  0
# city                      0
# bd                        0
# gender                    0
# registered_via            0
# registration_init_time    0
# dtype: int64

# %%
# no duplicates

df1.duplicated().any()
# Out:
# False

# %%
df1
# Out:
#                                                 msno  is_churn  city  bd  \
# 0       ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         1     5  28
# 1       f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1    13  20
# 2       zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1    13  18
# 3       K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1    13  35
# 4       moRTKhKIDvb+C8ZHOgmaF4dXMLk0jOn65d7a8tQ2Eds=         1     9  28
# ...                                              ...       ...   ...  ..
# 377023  SjVZDYaiKgEHpFX1PcFDS94b9CFdaHjg78rfumtm/F4=         0    15  19
# 377024  5NE9tsGhg7HbFNMdPT+3tytaIKG5013bBQG2vQTe+OI=         0     4  23
# 377025  /QlhSIWEZelYnwttYJSQL50EJJ2yRV+ThQIVQLvctp8=         0     8  25
# 377026  OHnZbu+EVaP+vN7Z+OfT5OMcp90MWFZonmM0o3pb8FY=         0    13  28
# 377027  iZE41tbAQ65rJq60olkJT4BJzuUAYgQdfbEemXe/TTk=         0     5  25
#
#         gender  registered_via  registration_init_time
# 0         male               3                20131223
# 1         male               3                20131223
# 2         male               3                20131227
# 3       female               7                20140125
# 4       female               3                20140202
# ...        ...             ...                     ...
# 377023    male               9                20110823
# 377024  female               9                20110826
# 377025  female               7                20110830
# 377026    male               7                20110831
# 377027  female               9                20110905
#
# [377028 rows x 7 columns]

# %%
#Transactions gives us payment details for each user as well as whether the subscription is still active

transdf = pd.read_csv(r"C:\Users\marsh\Desktop\Springboard\Capstone2\transactions_v2.csv")
transdf
# Out:
#                                                  msno  payment_method_id  \
# 0        ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=                 32
# 1        ++lvGPJOinuin/8esghpnqdljm6NXS8m8Zwchc7gOeA=                 41
# 2        +/GXNtXWQVfKrEDqYAzcSw2xSPYMKWNj22m+5XkVQZc=                 36
# 3        +/w1UrZwyka4C9oNH3+Q8fUf3fD8R3EwWrx57ODIsqk=                 36
# 4        +00PGzKTYqtnb65mPKPyeHXcZEwqiEzktpQksaaSC3c=                 41
# ...                                               ...                ...
# 1431004  zwF50wwaJI2TBKWhB42HRBJ6EQK0jgSo1Xmwb9Jq3SU=                 32
# 1431005  zx/h5MzQQmsSat04wSfGpHp6N8aWLLwM1+7OV7ujmPY=                 41
# 1431006  zxvgjIKjy18Fm+cIWUfYKr68z09+ILBxuMW0DnbeUZ8=                 41
# 1431007  zzNhkExbpzmpjp9tXefiCUBtgNLgS+vZE7fFfTRDJVc=                 38
# 1431008  zzZmdSzz7J9oyC/5nHr/HBvWg6k+p2W15b6lt/VKUQE=                 32
#
#          payment_plan_days  plan_list_price  actual_amount_paid  \
# 0                       90              298                 298
# 1                       30              149                 149
# 2                       30              180                 180
# 3                       30              180                 180
# 4                       30               99                  99
# ...                    ...              ...                 ...
# 1431004                180              536                 536
# 1431005                 30              149                 149
# 1431006                 30               99                  99
# 1431007                 30              149                 149
# 1431008                180              699                 699
#
#          is_auto_renew  transaction_date  membership_expire_date  is_cancel
# 0                    0          20170131                20170504          0
# 1                    1          20150809                20190412          0
# 2                    1          20170303                20170422          0
# 3                    1          20170329                20170331          1
# 4                    1          20170323                20170423          0
# ...                ...               ...                     ...        ...
# 1431004              0          20170215                20170817          0
# 1431005              1          20170306                20170406          0
# 1431006              1          20170308                20170408          0
# 1431007              0          20170318                20170417          0
# 1431008              0          20161212                20170613          0
#
# [1431009 rows x 9 columns]

# %%
# The churn/renewal definition can be tricky due to KKBox's subscription model. Since the majority of KKBox's subscription 
# length is 30 days, a lot of users re-subscribe every month. The key fields to determine churn/renewal are transaction date,
# membership expiration date, and is_cancel. Note that the is_cancel field indicates whether a user actively cancels a 
# subscription. Subscription cancellation does not imply the user has churned. A user may cancel service subscription due to 
# change of service plans or other reasons. The criteria of "churn" is no new valid service subscription within 30 days after 
# the current membership expires.

transdf.duplicated().any()
# Out:
# False

# %%
transdf.msno.duplicated().sum()
# Out:
# 233959

# %%
# there are now row duplicates but there are duplicate user ids. Why are there multiple transaction dates for the same user, all in such a small time window?

duplicate = transdf[transdf.msno.duplicated()]
duplicate
# Out:
#                                                  msno  payment_method_id  \
# 83       +hXL1k++YSAJWSqyZLw90gIMFQXG3zv639GSK8f5Qn0=                 41
# 145      /BndJt9YSOh1kzEykXyHrQZKl943rqFrzR9efW2b7wE=                 39
# 698      4CHAQfq5SJiIZSSs/q61nSjpD3r1kfO8S9R9+UJvie4=                 41
# 1715     DgyEYyyhcOun8D+8Ln2Lpx8orfCrV8L6Fgvt/22a4ec=                 15
# 1739     Du6MaYC9gJo8KEu2QVKWpzl448tbmM2iTImTAHAg8EY=                 41
# ...                                               ...                ...
# 1430992  zqacrLPJEEQDwPwvmVh19LogZVcX1hxg/rmFgOACQRg=                 39
# 1430993  zqsH77C0tnmJzRXyJ2EGECaaUOE0AT9rrO/BaGAD9is=                 41
# 1430996  zs1Oc+7NwsWhcCeZ287H+lUakejR2LdNKVLPaQcUTJ8=                 37
# 1430999  zt/SmfsXujpaCmvgdjvWa1MYYzLQLJkYFdr2Z7I0+Wo=                 39
# 1431002  zunw3CPwPJTzf7oIFzjoaukmM/rEGU3S1uIr/G2aY1I=                 39
#
#          payment_plan_days  plan_list_price  actual_amount_paid  \
# 83                      30              149                 149
# 145                     30              149                 149
# 698                     30               99                  99
# 1715                   360             1200                1200
# 1739                    30              149                 149
# ...                    ...              ...                 ...
# 1430992                 30              149                 149
# 1430993                 30              129                 129
# 1430996                 30              149                 149
# 1430999                 30              149                 149
# 1431002                 30              149                 149
#
#          is_auto_renew  transaction_date  membership_expire_date  is_cancel
# 83                   1          20151221                20181122          0
# 145                  1          20170331                20170524          0
# 698                  1          20170322                20170422          0
# 1715                 0          20170120                20180117          0
# 1739                 1          20151015                20191115          0
# ...                ...               ...                     ...        ...
# 1430992              1          20170331                20170523          0
# 1430993              1          20170310                20170310          1
# 1430996              1          20170313                20170412          0
# 1430999              1          20170228                20170425          0
# 1431002              1          20170228                20170404          0
#
# [233959 rows x 9 columns]

# %%
transdf[transdf.msno == '72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=']['transaction_date'].value_counts()
# Out:
# 20160720    98
# 20160731    55
# 20160721    54
# 20160728     1
# Name: transaction_date, dtype: int64

# %%
transdf[transdf.msno == '72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=']['membership_expire_date'].value_counts()
# Out:
# 20201125    1
# 20180103    1
# 20190410    1
# 20190619    1
# 20190403    1
#            ..
# 20190717    1
# 20201202    1
# 20180523    1
# 20190515    1
# 20181107    1
# Name: membership_expire_date, Length: 208, dtype: int64

# %%
transdf[transdf.msno == 'WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=']
# Out:
#                                                  msno  payment_method_id  \
# 10936    WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=                 38
# 25214    WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=                 38
# 46591    WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=                 38
# 46592    WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=                 38
# 53863    WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=                 38
# ...                                               ...                ...
# 1413421  WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=                 38
# 1413422  WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=                 38
# 1413423  WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=                 38
# 1427749  WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=                 38
# 1427750  WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=                 38
#
#          payment_plan_days  plan_list_price  actual_amount_paid  \
# 10936                    7                0                   0
# 25214                    7                0                   0
# 46591                    7                0                   0
# 46592                    7                0                   0
# 53863                    7                0                   0
# ...                    ...              ...                 ...
# 1413421                  7                0                   0
# 1413422                  7                0                   0
# 1413423                  7                0                   0
# 1427749                  7                0                   0
# 1427750                  7                0                   0
#
#          is_auto_renew  transaction_date  membership_expire_date  is_cancel
# 10936                0          20170216                20190529          0
# 25214                0          20170216                20190731          0
# 46591                0          20170214                20180627          0
# 46592                0          20170216                20181010          0
# 53863                0          20170212                20170510          0
# ...                ...               ...                     ...        ...
# 1413421              0          20170212                20170517          0
# 1413422              0          20170214                20180418          0
# 1413423              0          20170216                20180926          0
# 1427749              0          20170216                20190501          0
# 1427750              0          20170216                20190619          0
#
# [145 rows x 9 columns]

# %%
# check for null values
transdf.isnull().sum()
# Out:
# msno                      0
# payment_method_id         0
# payment_plan_days         0
# plan_list_price           0
# actual_amount_paid        0
# is_auto_renew             0
# transaction_date          0
# membership_expire_date    0
# is_cancel                 0
# dtype: int64

# %%
transdf.describe()
# Out:
#        payment_method_id  payment_plan_days  plan_list_price  \
# count       1.431009e+06       1.431009e+06     1.431009e+06
# mean        3.791835e+01       6.601770e+01     2.817870e+02
# std         4.964805e+00       1.024864e+02     4.351861e+02
# min         2.000000e+00       0.000000e+00     0.000000e+00
# 25%         3.600000e+01       3.000000e+01     9.900000e+01
# 50%         4.000000e+01       3.000000e+01     1.490000e+02
# 75%         4.100000e+01       3.000000e+01     1.490000e+02
# max         4.100000e+01       4.500000e+02     2.000000e+03
#
#        actual_amount_paid  is_auto_renew  transaction_date  \
# count        1.431009e+06   1.431009e+06      1.431009e+06
# mean         2.813172e+02   7.853025e-01      2.016848e+07
# std          4.354200e+02   4.106124e-01      4.858797e+03
# min          0.000000e+00   0.000000e+00      2.015010e+07
# 25%          9.900000e+01   1.000000e+00      2.017023e+07
# 50%          1.490000e+02   1.000000e+00      2.017031e+07
# 75%          1.490000e+02   1.000000e+00      2.017032e+07
# max          2.000000e+03   1.000000e+00      2.017033e+07
#
#        membership_expire_date     is_cancel
# count            1.431009e+06  1.431009e+06
# mean             2.017110e+07  2.455121e-02
# std              3.032367e+03  1.547529e-01
# min              2.016042e+07  0.000000e+00
# 25%              2.017041e+07  0.000000e+00
# 50%              2.017042e+07  0.000000e+00
# 75%              2.017050e+07  0.000000e+00
# max              2.036102e+07  1.000000e+00

# %%
transdf.dtypes
# Out:
# msno                      object
# payment_method_id          int64
# payment_plan_days          int64
# plan_list_price            int64
# actual_amount_paid         int64
# is_auto_renew              int64
# transaction_date           int64
# membership_expire_date     int64
# is_cancel                  int64
# dtype: object

# %%
transdf.is_cancel.value_counts()
# Out:
# 0    1395876
# 1      35133
# Name: is_cancel, dtype: int64

# %%
transdf.is_auto_renew.value_counts()
# Out:
# 1    1123775
# 0     307234
# Name: is_auto_renew, dtype: int64

# %%
transdf[transdf.msno == '5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=']
# Out:
#                                                  msno  payment_method_id  \
# 892      5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=                 38
# 7955     5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=                 38
# 7956     5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=                 38
# 15076    5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=                 38
# 15077    5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=                 38
# ...                                               ...                ...
# 1381997  5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=                 38
# 1396163  5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=                 38
# 1403301  5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=                 38
# 1424774  5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=                 38
# 1424775  5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=                 38
#
#          payment_plan_days  plan_list_price  actual_amount_paid  \
# 892                      7                0                   0
# 7955                     7                0                   0
# 7956                     7                0                   0
# 15076                    7                0                   0
# 15077                    7                0                   0
# ...                    ...              ...                 ...
# 1381997                  7                0                   0
# 1396163                  7                0                   0
# 1403301                  7                0                   0
# 1424774                  7                0                   0
# 1424775                  7                0                   0
#
#          is_auto_renew  transaction_date  membership_expire_date  is_cancel
# 892                  0          20160104                20180610          0
# 7955                 0          20151215                20171119          0
# 7956                 0          20160104                20190915          0
# 15076                0          20160107                20200301          0
# 15077                0          20160107                20200426          0
# ...                ...               ...                     ...        ...
# 1381997              0          20160104                20190310          0
# 1396163              0          20160104                20190505          0
# 1403301              0          20160104                20181007          0
# 1424774              0          20160104                20181028          0
# 1424775              0          20160108                20200712          0
#
# [172 rows x 9 columns]

# %%
# merge df1 to transdf

df2 = df1.merge(transdf, on ='msno', how = 'inner')
df2
# Out:
#                                                 msno  is_churn  city  bd  \
# 0       f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1    13  20
# 1       zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1    13  18
# 2       zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1    13  18
# 3       K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1    13  35
# 4       K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1    13  35
# ...                                              ...       ...   ...  ..
# 463696  5NE9tsGhg7HbFNMdPT+3tytaIKG5013bBQG2vQTe+OI=         0     4  23
# 463697  /QlhSIWEZelYnwttYJSQL50EJJ2yRV+ThQIVQLvctp8=         0     8  25
# 463698  OHnZbu+EVaP+vN7Z+OfT5OMcp90MWFZonmM0o3pb8FY=         0    13  28
# 463699  iZE41tbAQ65rJq60olkJT4BJzuUAYgQdfbEemXe/TTk=         0     5  25
# 463700  iZE41tbAQ65rJq60olkJT4BJzuUAYgQdfbEemXe/TTk=         0     5  25
#
#         gender  registered_via  registration_init_time  payment_method_id  \
# 0         male               3                20131223                 36
# 1         male               3                20131227                 17
# 2         male               3                20131227                 15
# 3       female               7                20140125                 41
# 4       female               7                20140125                 41
# ...        ...             ...                     ...                ...
# 463696  female               9                20110826                 37
# 463697  female               7                20110830                 41
# 463698    male               7                20110831                 40
# 463699  female               9                20110905                 39
# 463700  female               9                20110905                 39
#
#         payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                      30              180                 180              0
# 1                      60                0                   0              0
# 2                      90              300                 300              0
# 3                      30               99                  99              1
# 4                      30               99                  99              1
# ...                   ...              ...                 ...            ...
# 463696                 30              149                 149              1
# 463697                 30              149                 149              1
# 463698                 30              149                 149              1
# 463699                 30              149                 149              1
# 463700                 30              149                 149              1
#
#         transaction_date  membership_expire_date  is_cancel
# 0               20170311                20170411          0
# 1               20170311                20170314          0
# 2               20170314                20170615          0
# 3               20170117                20170721          0
# 4               20161201                20170605          0
# ...                  ...                     ...        ...
# 463696          20170326                20170425          0
# 463697          20170317                20170417          0
# 463698          20170304                20170403          0
# 463699          20170331                20170513          0
# 463700          20170228                20170413          0
#
# [463701 rows x 15 columns]

# %%
# user table contains details of a user's listening behaviour. Num denotes the % of song completion

userdf = pd.read_csv(r"C:\Users\marsh\Desktop\Springboard\Capstone2\user_logs_v2.csv")
userdf
# Out:
#                                                   msno      date  num_25  \
# 0         u9E91QDTvHLq6NXjEaWv8u4QIqhrHk72kE+w31Gnhdg=  20170331       8
# 1         nTeWW/eOZA/UHKdD5L7DEqKKFTjaAj3ALLPoAWsU8n0=  20170330       2
# 2         2UqkWXwZbIjs03dHLU9KHJNNEvEkZVzm69f3jCS+uLI=  20170331      52
# 3         ycwLc+m2O0a85jSLALtr941AaZt9ai8Qwlg9n0Nql5U=  20170331     176
# 4         EGcbTofOSOkMmQyN1NMLxHEXJ1yV3t/JdhGwQ9wXjnI=  20170331       2
# ...                                                ...       ...     ...
# 18396357  FGpiy2mB+vXLKziYRcY/xJcJEFJfRDfUqlU+p760f7E=  20170314       0
# 18396358  iZRjKNMrw5ffEbfXODLhV/0tJLPbOH3am1WYDgqBf8Q=  20170306       0
# 18396359  yztw4Y0EggG0w2wPkbMZx7ke7saSx7dLSfMheHZG/DQ=  20170331       0
# 18396360  swCHwkNx30/aENjq30qqaLlm7bUUytbMXdz1bH7g0Jk=  20170307       0
# 18396361  pDQSIFZchNPmOproRzaNzy51/8yRXzLK3vvDXKzzGLQ=  20170329       0
#
#           num_50  num_75  num_985  num_100  num_unq  total_secs
# 0              4       0        1       21       18    6309.273
# 1              2       1        0        9       11    2390.699
# 2              3       5        3       84      110   23203.337
# 3              4       2        2       19      191    7100.454
# 4              1       0        1      112       93   28401.558
# ...          ...     ...      ...      ...      ...         ...
# 18396357       0       0        0        1        1     248.058
# 18396358       0       0        0        1        1     311.000
# 18396359       0       0        0       17        1    3973.189
# 18396360       0       0        1        0        1     179.278
# 18396361       0       0        0        1        1     264.288
#
# [18396362 rows x 9 columns]

# %%
userdfdup = userdf[userdf.msno.duplicated()]
userdfdup.msno.value_counts()
# Out:
# +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=    30
# IsW9Z97sfb46JJ8yA6BrpxN0tphytU6PlWs2UYhsKMI=    30
# FeQoey6MjhjCmqS4nL3nROl9EEj4IOOjzaLLIdnRd6M=    30
# MHIQR0Nj3FQR5HhlfhzNiWmPPjtS2wSNPhQM6UylL1Q=    30
# nJ7TOQEv5WZA5KHDckVtxlQbXAsJYT9s3BNexbauTTY=    30
#                                                 ..
# 4iMd0o7pKhkXKUEZq3eW4k9ObbJVua6nn+hRBm8xZY0=     1
# QXwqQbsV7tF02kmQzE7OeuP2kHDkOr3zd1PcPx+4dsg=     1
# UK9oQnga5ZeIMDF+mAOuqgzAHZ2VoDwVu/IXs8VWvRY=     1
# lhFB1CW8cihD8CPxaYYvDp2bGWgIFedOWgreAvCycAM=     1
# swCHwkNx30/aENjq30qqaLlm7bUUytbMXdz1bH7g0Jk=     1
# Name: msno, Length: 1016672, dtype: int64

# %%
userdf[userdf.msno == '5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=']
# Out:
# (24, 9)

# %%
userdf[userdf['msno'] == '+PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw='].sort_values('date')
# Out:
#                                                   msno      date  num_25  \
# 9202275   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170301      10
# 6388245   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170302      25
# 17446699  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170303      13
# 10821115  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170304      26
# 2011891   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170305       7
# 7308332   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170306       2
# 11749605  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170307      77
# 16190021  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170308      17
# 16023814  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170309      31
# 11213179  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170310       7
# 5318757   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170311      31
# 6266341   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170312       6
# 11677721  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170313      32
# 14196851  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170314      23
# 9996200   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170315       8
# 9890498   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170316      11
# 9340942   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170317       5
# 12458134  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170318       9
# 2632211   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170319      13
# 14878615  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170320       8
# 915096    +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170321      15
# 17396110  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170322      18
# 4298502   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170323      43
# 1354436   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170324     149
# 16680001  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170325      10
# 11140974  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170326       8
# 3783597   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170327      13
# 10726926  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170328      77
# 7529910   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170329       6
# 5823027   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170330      15
# 15916152  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170331       7
#
#           num_50  num_75  num_985  num_100  num_unq  total_secs
# 9202275        4       3        5       12       21    5192.039
# 6388245        2       2        5       27       50    8516.790
# 17446699       2       5        1       10       25    3711.547
# 10821115       2       3        6       25       53    8473.527
# 2011891        5       4        2       17       28    5564.371
# 7308332        3       4        6       14       20    5671.623
# 11749605      18      10       14       15      122   10269.273
# 16190021       6       5        6       53       77   14827.783
# 16023814       4       6        3       40       79   11316.426
# 11213179       2       2        5       24       33    8057.056
# 5318757       10       8        5       16       57    8113.423
# 6266341        3       5        5       18       31    7076.200
# 11677721       3       4       12       34       73   12198.477
# 14196851       8       6        4       16       49    6839.944
# 9996200        3       4        5        9       21    4501.055
# 9890498        4       0        2       17       20    5086.203
# 9340942        3       5       10       22       29    8830.213
# 12458134      11       9        8       24       37    9167.890
# 2632211        4       2       10       34       35   11433.651
# 14878615       5       4        7       12       18    5134.095
# 915096         7       5       11       10       39    6686.607
# 17396110       6       1        8       10       31    5105.462
# 4298502        5       3       10       17       65    7446.880
# 1354436       40      22       17       33      164   19057.543
# 16680001       3       5        9       10       22    5300.714
# 11140974       4       3        4      107      104   28399.482
# 3783597        8       8        8      108       47   29461.527
# 10726926      15       8       15       19      100   11062.831
# 7529910        2       4        3       10       15    3974.631
# 5823027        9       4        5       63       34   14689.203
# 15916152       4       3        7       14       24    5754.613

# %%
# merge df2 with user logs df, on user id and transaction/user log dates

df3 = df2.merge(userdf, left_on= ['msno','transaction_date'], right_on = ['msno','date'])

# %%
df3
# Out:
#                                                 msno  is_churn  city  bd  \
# 0       f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1    13  20
# 1       zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1    13  18
# 2       K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1    13  35
# 3       moRTKhKIDvb+C8ZHOgmaF4dXMLk0jOn65d7a8tQ2Eds=         1     9  28
# 4       dW/tPZMDh2Oz/ksduEctJbsz0MXw3kay/1AlZCq3EbI=         1    13  21
# ...                                              ...       ...   ...  ..
# 229721  q18eydRjoRGx2rYbZZxB4jlBZa22VTmCWbgrXEWJfTA=         0    13  27
# 229722  RarUowfkW6CrHjw8jMNjFURi17Ja0/docu2tyVfm5jI=         0    13  45
# 229723  5dXGSlRH5LQVFbTUGQwfyyaFb8w/FVqfTS8N4aNEots=         0     5  21
# 229724  /QlhSIWEZelYnwttYJSQL50EJJ2yRV+ThQIVQLvctp8=         0     8  25
# 229725  OHnZbu+EVaP+vN7Z+OfT5OMcp90MWFZonmM0o3pb8FY=         0    13  28
#
#         gender  registered_via  registration_init_time  payment_method_id  \
# 0         male               3                20131223                 36
# 1         male               3                20131227                 17
# 2       female               7                20140125                 41
# 3       female               3                20140202                 38
# 4       female               9                20140212                 38
# ...        ...             ...                     ...                ...
# 229721    male               7                20110813                 41
# 229722    male               9                20110816                 36
# 229723    male               9                20110819                 38
# 229724  female               7                20110830                 41
# 229725    male               7                20110831                 40
#
#         payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                      30              180                 180              0
# 1                      60                0                   0              0
# 2                      30               99                  99              1
# 3                     410             1788                1788              0
# 4                      90              477                 477              0
# ...                   ...              ...                 ...            ...
# 229721                 30              129                 129              1
# 229722                 30              180                 180              0
# 229723                 30              149                 149              0
# 229724                 30              149                 149              1
# 229725                 30              149                 149              1
#
#         transaction_date  membership_expire_date  is_cancel      date  num_25  \
# 0               20170311                20170411          0  20170311       0
# 1               20170311                20170314          0  20170311       1
# 2               20170316                20170918          0  20170316       0
# 3               20170324                20180513          0  20170324       3
# 4               20170328                20170707          0  20170328      15
# ...                  ...                     ...        ...       ...     ...
# 229721          20170327                20170428          0  20170327      27
# 229722          20170328                20170427          0  20170328       0
# 229723          20170309                20170408          0  20170309      13
# 229724          20170317                20170417          0  20170317      16
# 229725          20170304                20170403          0  20170304       0
#
#         num_50  num_75  num_985  num_100  num_unq  total_secs
# 0            0       0        0        7        7    1681.037
# 1            0       0        0        0        1      48.437
# 2            1       0        0      136       32   33044.856
# 3            0       3        1       41       30   10846.695
# 4           15       2        1       19       46    6432.444
# ...        ...     ...      ...      ...      ...         ...
# 229721       0       2        1       22       45    6359.268
# 229722       1       0        0       13       12    3457.122
# 229723       7      10       11       40       44   13572.611
# 229724       4       6        3      108       96   26577.418
# 229725       0       0        0        8        8    2046.066
#
# [229726 rows x 23 columns]

# %%
# no null values

df3.isnull().any()
# Out:
# msno                      False
# is_churn                  False
# city                      False
# bd                        False
# gender                    False
# registered_via            False
# registration_init_time    False
# payment_method_id         False
# payment_plan_days         False
# plan_list_price           False
# actual_amount_paid        False
# is_auto_renew             False
# transaction_date          False
# membership_expire_date    False
# is_cancel                 False
# date                      False
# num_25                    False
# num_50                    False
# num_75                    False
# num_985                   False
# num_100                   False
# num_unq                   False
# total_secs                False
# dtype: bool

# %%
# no duplciated values

df3.duplicated().any()
# Out:
# False

# %%
# rename columns and change dtypes for date columns

df3 = df3.rename(columns = {'msno' : 'userid', 'bd': 'age'})
df3['registration_init_time'] =  pd.to_datetime(df3['registration_init_time'].astype(str), format='%Y%m%d')
df3['transaction_date'] =  pd.to_datetime(df3['transaction_date'].astype(str), format='%Y%m%d')
df3['membership_expire_date'] =  pd.to_datetime(df3['membership_expire_date'].astype(str), format='%Y%m%d')

# %%
# change dtypes for string and category columns

df3.date = pd.to_datetime(df3.date.astype(str), format='%Y%m%d')
df3.userid = df3.userid.astype(str)
df3.is_churn = df3.is_churn.astype('category')
df3.gender = df3.gender.astype(str)
df3.is_cancel = df3.is_cancel.astype('category')

# %%
df3.userid.value_counts().head()
# Out:
# 791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=    22
# MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=    17
# WBpgK5pHlEe6kkc73mkEIXRsPUSFuuIImZ8tD9rQ7C0=    13
# qP66pCFEiIONygGX9baEJQ5JKpVyFo2ao0AmTuw5ACY=    12
# TKDg6+l5f7bp86Poq2ma/XotpfIaLHipbwJjvrWBmlI=     8
# Name: userid, dtype: int64

# %%
# looks like only membership_expire_date is different and accounts for a majority of the duplicates. We must keep these 
# since they are important to determining user churn.

df3[df3.userid == '791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=']
# Out:
#                                               userid is_churn  city  age  \
# 146343  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146344  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146345  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146346  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146347  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146348  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146349  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146350  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146351  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146352  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146353  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146354  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146355  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146356  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146357  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146358  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146359  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146360  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146361  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146362  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146363  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
# 146364  791c32ArWs05ZCpF+brfdTcgsMsOIKIxMCUe1Qh4OKE=        1     4   22
#
#         gender  registered_via registration_init_time  payment_method_id  \
# 146343  female               9             2015-04-15                 38
# 146344  female               9             2015-04-15                 38
# 146345  female               9             2015-04-15                 38
# 146346  female               9             2015-04-15                 38
# 146347  female               9             2015-04-15                 38
# 146348  female               9             2015-04-15                 38
# 146349  female               9             2015-04-15                 38
# 146350  female               9             2015-04-15                 38
# 146351  female               9             2015-04-15                 38
# 146352  female               9             2015-04-15                 38
# 146353  female               9             2015-04-15                 38
# 146354  female               9             2015-04-15                 38
# 146355  female               9             2015-04-15                 38
# 146356  female               9             2015-04-15                 38
# 146357  female               9             2015-04-15                 38
# 146358  female               9             2015-04-15                 38
# 146359  female               9             2015-04-15                 38
# 146360  female               9             2015-04-15                 38
# 146361  female               9             2015-04-15                 38
# 146362  female               9             2015-04-15                 38
# 146363  female               9             2015-04-15                 38
# 146364  female               9             2015-04-15                 38
#
#         payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 146343                  7               35                  35              0
# 146344                  7               35                  35              0
# 146345                  7               35                  35              0
# 146346                  7               35                  35              0
# 146347                  7               35                  35              0
# 146348                  7               35                  35              0
# 146349                  7               35                  35              0
# 146350                  7               35                  35              0
# 146351                  7               35                  35              0
# 146352                  7               35                  35              0
# 146353                  7               35                  35              0
# 146354                  7               35                  35              0
# 146355                  7               35                  35              0
# 146356                  7               35                  35              0
# 146357                  7               35                  35              0
# 146358                  7               35                  35              0
# 146359                  7               35                  35              0
# 146360                  7               35                  35              0
# 146361                  7               35                  35              0
# 146362                  7               35                  35              0
# 146363                  7               35                  35              0
# 146364                  7               35                  35              0
#
#        transaction_date membership_expire_date is_cancel       date  num_25  \
# 146343       2017-03-18             2017-06-15         0 2017-03-18       0
# 146344       2017-03-18             2017-09-14         0 2017-03-18       0
# 146345       2017-03-18             2017-07-27         0 2017-03-18       0
# 146346       2017-03-18             2017-06-08         0 2017-03-18       0
# 146347       2017-03-18             2017-07-13         0 2017-03-18       0
# 146348       2017-03-18             2017-06-01         0 2017-03-18       0
# 146349       2017-03-18             2017-08-10         0 2017-03-18       0
# 146350       2017-03-18             2017-08-31         0 2017-03-18       0
# 146351       2017-03-18             2017-07-06         0 2017-03-18       0
# 146352       2017-03-18             2017-07-20         0 2017-03-18       0
# 146353       2017-03-18             2017-08-24         0 2017-03-18       0
# 146354       2017-03-18             2017-08-17         0 2017-03-18       0
# 146355       2017-03-18             2017-08-03         0 2017-03-18       0
# 146356       2017-03-18             2017-06-29         0 2017-03-18       0
# 146357       2017-03-18             2017-06-22         0 2017-03-18       0
# 146358       2017-03-18             2017-09-07         0 2017-03-18       0
# 146359       2017-03-01             2017-05-25         0 2017-03-01       2
# 146360       2017-03-01             2017-05-04         0 2017-03-01       2
# 146361       2017-03-01             2017-05-11         0 2017-03-01       2
# 146362       2017-03-01             2017-04-20         0 2017-03-01       2
# 146363       2017-03-01             2017-04-27         0 2017-03-01       2
# 146364       2017-03-01             2017-05-18         0 2017-03-01       2
#
#         num_50  num_75  num_985  num_100  num_unq  total_secs
# 146343       0       0        0        9        4    1957.162
# 146344       0       0        0        9        4    1957.162
# 146345       0       0        0        9        4    1957.162
# 146346       0       0        0        9        4    1957.162
# 146347       0       0        0        9        4    1957.162
# 146348       0       0        0        9        4    1957.162
# 146349       0       0        0        9        4    1957.162
# 146350       0       0        0        9        4    1957.162
# 146351       0       0        0        9        4    1957.162
# 146352       0       0        0        9        4    1957.162
# 146353       0       0        0        9        4    1957.162
# 146354       0       0        0        9        4    1957.162
# 146355       0       0        0        9        4    1957.162
# 146356       0       0        0        9        4    1957.162
# 146357       0       0        0        9        4    1957.162
# 146358       0       0        0        9        4    1957.162
# 146359       1       0        0        8       11    2893.174
# 146360       1       0        0        8       11    2893.174
# 146361       1       0        0        8       11    2893.174
# 146362       1       0        0        8       11    2893.174
# 146363       1       0        0        8       11    2893.174
# 146364       1       0        0        8       11    2893.174

# %%
# looks like only membership_expire_date is different and accounts for a majority of the duplicates. We must keep these 
# since they are important to determining user churn.

df3[df3.userid == 'MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=']
# Out:
#                                               userid is_churn  city  age  \
# 144617  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144618  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144619  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144620  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144621  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144622  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144623  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144624  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144625  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144626  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144627  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144628  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144629  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144630  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144631  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144632  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
# 144633  MFrEH81DqeRbBIYFssxgeyQ0J5eq0JCQSt6jkx+9/ps=        1     5   22
#
#         gender  registered_via registration_init_time  payment_method_id  \
# 144617  female               4             2017-02-28                 38
# 144618  female               4             2017-02-28                 38
# 144619  female               4             2017-02-28                 38
# 144620  female               4             2017-02-28                 38
# 144621  female               4             2017-02-28                 38
# 144622  female               4             2017-02-28                 38
# 144623  female               4             2017-02-28                 38
# 144624  female               4             2017-02-28                 38
# 144625  female               4             2017-02-28                 38
# 144626  female               4             2017-02-28                 38
# 144627  female               4             2017-02-28                 38
# 144628  female               4             2017-02-28                 38
# 144629  female               4             2017-02-28                 38
# 144630  female               4             2017-02-28                 38
# 144631  female               4             2017-02-28                 38
# 144632  female               4             2017-02-28                 38
# 144633  female               4             2017-02-28                 38
#
#         payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 144617                  7                0                   0              0
# 144618                  7                0                   0              0
# 144619                  7                0                   0              0
# 144620                  7                0                   0              0
# 144621                  7                0                   0              0
# 144622                  7                0                   0              0
# 144623                  7                0                   0              0
# 144624                  7                0                   0              0
# 144625                  7                0                   0              0
# 144626                  7                0                   0              0
# 144627                  7                0                   0              0
# 144628                  7                0                   0              0
# 144629                  7                0                   0              0
# 144630                  7                0                   0              0
# 144631                  7                0                   0              0
# 144632                  7                0                   0              0
# 144633                  7                0                   0              0
#
#        transaction_date membership_expire_date is_cancel listen_date  num_25  \
# 144617       2017-03-11             2017-04-29         0  2017-03-11       5
# 144618       2017-03-11             2017-07-01         0  2017-03-11       5
# 144619       2017-03-11             2017-05-06         0  2017-03-11       5
# 144620       2017-03-11             2017-04-15         0  2017-03-11       5
# 144621       2017-03-11             2017-05-13         0  2017-03-11       5
# 144622       2017-03-11             2017-03-25         0  2017-03-11       5
# 144623       2017-03-11             2017-06-03         0  2017-03-11       5
# 144624       2017-03-11             2017-06-10         0  2017-03-11       5
# 144625       2017-03-11             2017-04-08         0  2017-03-11       5
# 144626       2017-03-11             2017-04-22         0  2017-03-11       5
# 144627       2017-03-11             2017-06-17         0  2017-03-11       5
# 144628       2017-03-11             2017-05-20         0  2017-03-11       5
# 144629       2017-03-11             2017-06-24         0  2017-03-11       5
# 144630       2017-03-11             2017-03-18         0  2017-03-11       5
# 144631       2017-03-11             2017-07-08         0  2017-03-11       5
# 144632       2017-03-11             2017-04-01         0  2017-03-11       5
# 144633       2017-03-11             2017-05-27         0  2017-03-11       5
#
#         num_50  num_75  num_985  num_100  num_unq  total_secs
# 144617       3       0        1       30       20    7231.145
# 144618       3       0        1       30       20    7231.145
# 144619       3       0        1       30       20    7231.145
# 144620       3       0        1       30       20    7231.145
# 144621       3       0        1       30       20    7231.145
# 144622       3       0        1       30       20    7231.145
# 144623       3       0        1       30       20    7231.145
# 144624       3       0        1       30       20    7231.145
# 144625       3       0        1       30       20    7231.145
# 144626       3       0        1       30       20    7231.145
# 144627       3       0        1       30       20    7231.145
# 144628       3       0        1       30       20    7231.145
# 144629       3       0        1       30       20    7231.145
# 144630       3       0        1       30       20    7231.145
# 144631       3       0        1       30       20    7231.145
# 144632       3       0        1       30       20    7231.145
# 144633       3       0        1       30       20    7231.145

# %%
# change date column name to listen_date

df3 = df3.rename(columns = {'date':'listen_date'})

# %%
df3
# Out:
#                                               userid is_churn  city  age  \
# 0       f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=        1    13   20
# 1       zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=        1    13   18
# 2       K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=        1    13   35
# 3       moRTKhKIDvb+C8ZHOgmaF4dXMLk0jOn65d7a8tQ2Eds=        1     9   28
# 4       dW/tPZMDh2Oz/ksduEctJbsz0MXw3kay/1AlZCq3EbI=        1    13   21
# ...                                              ...      ...   ...  ...
# 229721  q18eydRjoRGx2rYbZZxB4jlBZa22VTmCWbgrXEWJfTA=        0    13   27
# 229722  RarUowfkW6CrHjw8jMNjFURi17Ja0/docu2tyVfm5jI=        0    13   45
# 229723  5dXGSlRH5LQVFbTUGQwfyyaFb8w/FVqfTS8N4aNEots=        0     5   21
# 229724  /QlhSIWEZelYnwttYJSQL50EJJ2yRV+ThQIVQLvctp8=        0     8   25
# 229725  OHnZbu+EVaP+vN7Z+OfT5OMcp90MWFZonmM0o3pb8FY=        0    13   28
#
#         gender  registered_via registration_init_time  payment_method_id  \
# 0         male               3             2013-12-23                 36
# 1         male               3             2013-12-27                 17
# 2       female               7             2014-01-25                 41
# 3       female               3             2014-02-02                 38
# 4       female               9             2014-02-12                 38
# ...        ...             ...                    ...                ...
# 229721    male               7             2011-08-13                 41
# 229722    male               9             2011-08-16                 36
# 229723    male               9             2011-08-19                 38
# 229724  female               7             2011-08-30                 41
# 229725    male               7             2011-08-31                 40
#
#         payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                      30              180                 180              0
# 1                      60                0                   0              0
# 2                      30               99                  99              1
# 3                     410             1788                1788              0
# 4                      90              477                 477              0
# ...                   ...              ...                 ...            ...
# 229721                 30              129                 129              1
# 229722                 30              180                 180              0
# 229723                 30              149                 149              0
# 229724                 30              149                 149              1
# 229725                 30              149                 149              1
#
#        transaction_date membership_expire_date is_cancel listen_date  num_25  \
# 0            2017-03-11             2017-04-11         0  2017-03-11       0
# 1            2017-03-11             2017-03-14         0  2017-03-11       1
# 2            2017-03-16             2017-09-18         0  2017-03-16       0
# 3            2017-03-24             2018-05-13         0  2017-03-24       3
# 4            2017-03-28             2017-07-07         0  2017-03-28      15
# ...                 ...                    ...       ...         ...     ...
# 229721       2017-03-27             2017-04-28         0  2017-03-27      27
# 229722       2017-03-28             2017-04-27         0  2017-03-28       0
# 229723       2017-03-09             2017-04-08         0  2017-03-09      13
# 229724       2017-03-17             2017-04-17         0  2017-03-17      16
# 229725       2017-03-04             2017-04-03         0  2017-03-04       0
#
#         num_50  num_75  num_985  num_100  num_unq  total_secs
# 0            0       0        0        7        7    1681.037
# 1            0       0        0        0        1      48.437
# 2            1       0        0      136       32   33044.856
# 3            0       3        1       41       30   10846.695
# 4           15       2        1       19       46    6432.444
# ...        ...     ...      ...      ...      ...         ...
# 229721       0       2        1       22       45    6359.268
# 229722       1       0        0       13       12    3457.122
# 229723       7      10       11       40       44   13572.611
# 229724       4       6        3      108       96   26577.418
# 229725       0       0        0        8        8    2046.066
#
# [229726 rows x 23 columns]

# %%
df3.dtypes
# Out:
# userid                            object
# is_churn                        category
# city                               int64
# age                                int64
# gender                            object
# registered_via                     int64
# registration_init_time    datetime64[ns]
# payment_method_id                  int64
# payment_plan_days                  int64
# plan_list_price                    int64
# actual_amount_paid                 int64
# is_auto_renew                      int64
# transaction_date          datetime64[ns]
# membership_expire_date    datetime64[ns]
# is_cancel                       category
# listen_date               datetime64[ns]
# num_25                             int64
# num_50                             int64
# num_75                             int64
# num_985                            int64
# num_100                            int64
# num_unq                            int64
# total_secs                       float64
# dtype: object
