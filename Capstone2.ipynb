# %%
# In this challenge the definition of churn is “no new valid service subscription within 30 days after the current membership expires.”

import csv
import pandas as pd
import os
import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import __version__ as sklearn_version
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.pipeline import make_pipeline

# %%
# Train table contains user ID and whether or not they churned

traindf = pd.read_csv(r"C:\Users\marsh\Desktop\Springboard\Capstone2\train_v2.csv")
traindf
# Out:
#                                                 msno  is_churn
# 0       ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         1
# 1       f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1
# 2       zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1
# 3       8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1
# 4       K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1
# ...                                              ...       ...
# 970955  OHnZbu+EVaP+vN7Z+OfT5OMcp90MWFZonmM0o3pb8FY=         0
# 970956  S92bDK//uI6hk3u1vuApro0qJBQOToBozZ7lL1yTC+w=         0
# 970957  eUa3xo16vpAjr43Cjlb6Kjf1NTILYyJIkBayJQdXWnw=         0
# 970958  iZE41tbAQ65rJq60olkJT4BJzuUAYgQdfbEemXe/TTk=         0
# 970959  oECkzJik4wKsbOEVY6UACLbmgM8qymFdb5cJaHrodY8=         0
#
# [970960 rows x 2 columns]

# %%
traindf.is_churn.value_counts()
# Out:
# 0    883630
# 1     87330
# Name: is_churn, dtype: int64

# %%
traindf = traindf.rename(columns = {'msno' : 'userid'})

# %%
traindf.isnull().sum()
# Out:
# msno        0
# is_churn    0
# dtype: int64

# %%
traindf.userid.duplicated().any()
# Out:
# False

# %%
#Transactions gives us payment details for each user as well as whether the subscription is still active

transdf = pd.read_csv(r"C:\Users\marsh\Desktop\Springboard\Capstone2\transactions_v2.csv")
transdf
# Out:
#                                                  msno  payment_method_id  \
# 0        ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=                 32
# 1        ++lvGPJOinuin/8esghpnqdljm6NXS8m8Zwchc7gOeA=                 41
# 2        +/GXNtXWQVfKrEDqYAzcSw2xSPYMKWNj22m+5XkVQZc=                 36
# 3        +/w1UrZwyka4C9oNH3+Q8fUf3fD8R3EwWrx57ODIsqk=                 36
# 4        +00PGzKTYqtnb65mPKPyeHXcZEwqiEzktpQksaaSC3c=                 41
# ...                                               ...                ...
# 1431004  zwF50wwaJI2TBKWhB42HRBJ6EQK0jgSo1Xmwb9Jq3SU=                 32
# 1431005  zx/h5MzQQmsSat04wSfGpHp6N8aWLLwM1+7OV7ujmPY=                 41
# 1431006  zxvgjIKjy18Fm+cIWUfYKr68z09+ILBxuMW0DnbeUZ8=                 41
# 1431007  zzNhkExbpzmpjp9tXefiCUBtgNLgS+vZE7fFfTRDJVc=                 38
# 1431008  zzZmdSzz7J9oyC/5nHr/HBvWg6k+p2W15b6lt/VKUQE=                 32
#
#          payment_plan_days  plan_list_price  actual_amount_paid  \
# 0                       90              298                 298
# 1                       30              149                 149
# 2                       30              180                 180
# 3                       30              180                 180
# 4                       30               99                  99
# ...                    ...              ...                 ...
# 1431004                180              536                 536
# 1431005                 30              149                 149
# 1431006                 30               99                  99
# 1431007                 30              149                 149
# 1431008                180              699                 699
#
#          is_auto_renew  transaction_date  membership_expire_date  is_cancel
# 0                    0          20170131                20170504          0
# 1                    1          20150809                20190412          0
# 2                    1          20170303                20170422          0
# 3                    1          20170329                20170331          1
# 4                    1          20170323                20170423          0
# ...                ...               ...                     ...        ...
# 1431004              0          20170215                20170817          0
# 1431005              1          20170306                20170406          0
# 1431006              1          20170308                20170408          0
# 1431007              0          20170318                20170417          0
# 1431008              0          20161212                20170613          0
#
# [1431009 rows x 9 columns]

# %%
transdf = transdf.rename(columns = {'msno' : 'userid'})

# %%
transdf.duplicated().any()
# Out:
# False

# %%
transdf.userid.duplicated().sum()
# Out:
# 131464

# %%
# there are now row duplicates but there are duplicate user ids. Why are there multiple transaction dates for the same user, all in such a small time window?

duplicate = transdf[transdf.msno.duplicated()]
duplicate
# Out:
#                                                  msno  payment_method_id  \
# 83       +hXL1k++YSAJWSqyZLw90gIMFQXG3zv639GSK8f5Qn0=                 41
# 145      /BndJt9YSOh1kzEykXyHrQZKl943rqFrzR9efW2b7wE=                 39
# 698      4CHAQfq5SJiIZSSs/q61nSjpD3r1kfO8S9R9+UJvie4=                 41
# 1715     DgyEYyyhcOun8D+8Ln2Lpx8orfCrV8L6Fgvt/22a4ec=                 15
# 1739     Du6MaYC9gJo8KEu2QVKWpzl448tbmM2iTImTAHAg8EY=                 41
# ...                                               ...                ...
# 1430992  zqacrLPJEEQDwPwvmVh19LogZVcX1hxg/rmFgOACQRg=                 39
# 1430993  zqsH77C0tnmJzRXyJ2EGECaaUOE0AT9rrO/BaGAD9is=                 41
# 1430996  zs1Oc+7NwsWhcCeZ287H+lUakejR2LdNKVLPaQcUTJ8=                 37
# 1430999  zt/SmfsXujpaCmvgdjvWa1MYYzLQLJkYFdr2Z7I0+Wo=                 39
# 1431002  zunw3CPwPJTzf7oIFzjoaukmM/rEGU3S1uIr/G2aY1I=                 39
#
#          payment_plan_days  plan_list_price  actual_amount_paid  \
# 83                      30              149                 149
# 145                     30              149                 149
# 698                     30               99                  99
# 1715                   360             1200                1200
# 1739                    30              149                 149
# ...                    ...              ...                 ...
# 1430992                 30              149                 149
# 1430993                 30              129                 129
# 1430996                 30              149                 149
# 1430999                 30              149                 149
# 1431002                 30              149                 149
#
#          is_auto_renew  transaction_date  membership_expire_date  is_cancel
# 83                   1          20151221                20181122          0
# 145                  1          20170331                20170524          0
# 698                  1          20170322                20170422          0
# 1715                 0          20170120                20180117          0
# 1739                 1          20151015                20191115          0
# ...                ...               ...                     ...        ...
# 1430992              1          20170331                20170523          0
# 1430993              1          20170310                20170310          1
# 1430996              1          20170313                20170412          0
# 1430999              1          20170228                20170425          0
# 1431002              1          20170228                20170404          0
#
# [233959 rows x 9 columns]

# %%
transdf[transdf.msno == '72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=']['transaction_date'].value_counts()
# Out:
# 20160720    98
# 20160731    55
# 20160721    54
# 20160728     1
# Name: transaction_date, dtype: int64

# %%
transdf[transdf.msno == '72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=']['membership_expire_date'].value_counts()
# Out:
# 20201125    1
# 20180103    1
# 20190410    1
# 20190619    1
# 20190403    1
#            ..
# 20190717    1
# 20201202    1
# 20180523    1
# 20190515    1
# 20181107    1
# Name: membership_expire_date, Length: 208, dtype: int64

# %%
transdf[transdf.userid == 'WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=']
# Out:
#        payment_method_id  payment_plan_days  plan_list_price  \
# count              145.0              145.0            145.0
# mean                38.0                7.0              0.0
# std                  0.0                0.0              0.0
# min                 38.0                7.0              0.0
# 25%                 38.0                7.0              0.0
# 50%                 38.0                7.0              0.0
# 75%                 38.0                7.0              0.0
# max                 38.0                7.0              0.0
#
#        actual_amount_paid  is_auto_renew  transaction_date  \
# count               145.0          145.0      1.450000e+02
# mean                  0.0            0.0      2.017022e+07
# std                   0.0            0.0      2.877713e+01
# min                   0.0            0.0      2.017021e+07
# 25%                   0.0            0.0      2.017021e+07
# 50%                   0.0            0.0      2.017022e+07
# 75%                   0.0            0.0      2.017022e+07
# max                   0.0            0.0      2.017031e+07
#
#        membership_expire_date  is_cancel
# count            1.450000e+02      145.0
# mean             2.018187e+07        0.0
# std              8.138960e+03        0.0
# min              2.017040e+07        0.0
# 25%              2.017121e+07        0.0
# 50%              2.018082e+07        0.0
# 75%              2.019050e+07        0.0
# max              2.020011e+07        0.0

# %%
# check for null values
transdf.isnull().sum()
# Out:
# msno                      0
# payment_method_id         0
# payment_plan_days         0
# plan_list_price           0
# actual_amount_paid        0
# is_auto_renew             0
# transaction_date          0
# membership_expire_date    0
# is_cancel                 0
# dtype: int64

# %%
# convert date column types from int to dates
transdf['transaction_date'] =  pd.to_datetime(transdf['transaction_date'].astype(str), format='%Y%m%d')
transdf['membership_expire_date'] =  pd.to_datetime(transdf['membership_expire_date'].astype(str), format='%Y%m%d')

# %%
transdf.describe()
# Out:
#        payment_method_id  payment_plan_days  plan_list_price  \
# count     1000000.000000     1000000.000000   1000000.000000
# mean           37.913627          65.996649       281.724649
# std             4.970272         102.463310       435.073503
# min             2.000000           0.000000         0.000000
# 25%            36.000000          30.000000        99.000000
# 50%            40.000000          30.000000       149.000000
# 75%            41.000000          30.000000       149.000000
# max            41.000000         450.000000      2000.000000
#
#        actual_amount_paid   is_auto_renew       is_cancel
# count      1000000.000000  1000000.000000  1000000.000000
# mean           281.243679        0.785229        0.024697
# std            435.307366        0.410664        0.155200
# min              0.000000        0.000000        0.000000
# 25%             99.000000        1.000000        0.000000
# 50%            149.000000        1.000000        0.000000
# 75%            149.000000        1.000000        0.000000
# max           2000.000000        1.000000        1.000000

# %%
transdf.dtypes
# Out:
# msno                              object
# payment_method_id                  int64
# payment_plan_days                  int64
# plan_list_price                    int64
# actual_amount_paid                 int64
# is_auto_renew                      int64
# transaction_date          datetime64[ns]
# membership_expire_date    datetime64[ns]
# is_cancel                          int64
# dtype: object

# %%
transdf.is_cancel.value_counts()
# Out:
# 0    975303
# 1     24697
# Name: is_cancel, dtype: int64

# %%
transdf.is_auto_renew.value_counts()
# Out:
# 1    785229
# 0    214771
# Name: is_auto_renew, dtype: int64

# %%
# user table contains details of a user's listening behaviour. Num denotes the % of song completion

userdf = pd.read_csv(r"C:\Users\marsh\Desktop\Springboard\Capstone2\user_logs_v2.csv")
userdf
# Out:
#                                                   msno      date  num_25  \
# 0         u9E91QDTvHLq6NXjEaWv8u4QIqhrHk72kE+w31Gnhdg=  20170331       8
# 1         nTeWW/eOZA/UHKdD5L7DEqKKFTjaAj3ALLPoAWsU8n0=  20170330       2
# 2         2UqkWXwZbIjs03dHLU9KHJNNEvEkZVzm69f3jCS+uLI=  20170331      52
# 3         ycwLc+m2O0a85jSLALtr941AaZt9ai8Qwlg9n0Nql5U=  20170331     176
# 4         EGcbTofOSOkMmQyN1NMLxHEXJ1yV3t/JdhGwQ9wXjnI=  20170331       2
# ...                                                ...       ...     ...
# 18396357  FGpiy2mB+vXLKziYRcY/xJcJEFJfRDfUqlU+p760f7E=  20170314       0
# 18396358  iZRjKNMrw5ffEbfXODLhV/0tJLPbOH3am1WYDgqBf8Q=  20170306       0
# 18396359  yztw4Y0EggG0w2wPkbMZx7ke7saSx7dLSfMheHZG/DQ=  20170331       0
# 18396360  swCHwkNx30/aENjq30qqaLlm7bUUytbMXdz1bH7g0Jk=  20170307       0
# 18396361  pDQSIFZchNPmOproRzaNzy51/8yRXzLK3vvDXKzzGLQ=  20170329       0
#
#           num_50  num_75  num_985  num_100  num_unq  total_secs
# 0              4       0        1       21       18    6309.273
# 1              2       1        0        9       11    2390.699
# 2              3       5        3       84      110   23203.337
# 3              4       2        2       19      191    7100.454
# 4              1       0        1      112       93   28401.558
# ...          ...     ...      ...      ...      ...         ...
# 18396357       0       0        0        1        1     248.058
# 18396358       0       0        0        1        1     311.000
# 18396359       0       0        0       17        1    3973.189
# 18396360       0       0        1        0        1     179.278
# 18396361       0       0        0        1        1     264.288
#
# [18396362 rows x 9 columns]

# %%
userdfdup = userdf[userdf.msno.duplicated()]
userdfdup.msno.value_counts()
# Out:
# +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=    30
# IsW9Z97sfb46JJ8yA6BrpxN0tphytU6PlWs2UYhsKMI=    30
# FeQoey6MjhjCmqS4nL3nROl9EEj4IOOjzaLLIdnRd6M=    30
# MHIQR0Nj3FQR5HhlfhzNiWmPPjtS2wSNPhQM6UylL1Q=    30
# nJ7TOQEv5WZA5KHDckVtxlQbXAsJYT9s3BNexbauTTY=    30
#                                                 ..
# 4iMd0o7pKhkXKUEZq3eW4k9ObbJVua6nn+hRBm8xZY0=     1
# QXwqQbsV7tF02kmQzE7OeuP2kHDkOr3zd1PcPx+4dsg=     1
# UK9oQnga5ZeIMDF+mAOuqgzAHZ2VoDwVu/IXs8VWvRY=     1
# lhFB1CW8cihD8CPxaYYvDp2bGWgIFedOWgreAvCycAM=     1
# swCHwkNx30/aENjq30qqaLlm7bUUytbMXdz1bH7g0Jk=     1
# Name: msno, Length: 1016672, dtype: int64

# %%
userdf[userdf['msno'] == '+PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=']
# Out:
#                                                   msno      date  num_25  \
# 915096    +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170321      15
# 1354436   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170324     149
# 2011891   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170305       7
# 2632211   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170319      13
# 3783597   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170327      13
# 4298502   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170323      43
# 5318757   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170311      31
# 5823027   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170330      15
# 6266341   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170312       6
# 6388245   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170302      25
# 7308332   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170306       2
# 7529910   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170329       6
# 9202275   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170301      10
# 9340942   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170317       5
# 9890498   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170316      11
# 9996200   +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170315       8
# 10726926  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170328      77
# 10821115  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170304      26
# 11140974  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170326       8
# 11213179  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170310       7
# 11677721  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170313      32
# 11749605  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170307      77
# 12458134  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170318       9
# 14196851  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170314      23
# 14878615  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170320       8
# 15916152  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170331       7
# 16023814  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170309      31
# 16190021  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170308      17
# 16680001  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170325      10
# 17396110  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170322      18
# 17446699  +PCyNW+cioNHafPsAKXRfBnOZnvSGrit4DfODkV8crw=  20170303      13
#
#           num_50  num_75  num_985  num_100  num_unq  total_secs
# 915096         7       5       11       10       39    6686.607
# 1354436       40      22       17       33      164   19057.543
# 2011891        5       4        2       17       28    5564.371
# 2632211        4       2       10       34       35   11433.651
# 3783597        8       8        8      108       47   29461.527
# 4298502        5       3       10       17       65    7446.880
# 5318757       10       8        5       16       57    8113.423
# 5823027        9       4        5       63       34   14689.203
# 6266341        3       5        5       18       31    7076.200
# 6388245        2       2        5       27       50    8516.790
# 7308332        3       4        6       14       20    5671.623
# 7529910        2       4        3       10       15    3974.631
# 9202275        4       3        5       12       21    5192.039
# 9340942        3       5       10       22       29    8830.213
# 9890498        4       0        2       17       20    5086.203
# 9996200        3       4        5        9       21    4501.055
# 10726926      15       8       15       19      100   11062.831
# 10821115       2       3        6       25       53    8473.527
# 11140974       4       3        4      107      104   28399.482
# 11213179       2       2        5       24       33    8057.056
# 11677721       3       4       12       34       73   12198.477
# 11749605      18      10       14       15      122   10269.273
# 12458134      11       9        8       24       37    9167.890
# 14196851       8       6        4       16       49    6839.944
# 14878615       5       4        7       12       18    5134.095
# 15916152       4       3        7       14       24    5754.613
# 16023814       4       6        3       40       79   11316.426
# 16190021       6       5        6       53       77   14827.783
# 16680001       3       5        9       10       22    5300.714
# 17396110       6       1        8       10       31    5105.462
# 17446699       2       5        1       10       25    3711.547

# %%
# members table includes a user's personal and registration information

memdf = pd.read_csv(r"C:\Users\marsh\Desktop\Springboard\Capstone2\members_v3.csv")

# %%
memdf['registration_init_time'] =  pd.to_datetime(memdf['registration_init_time'].astype(str), format='%Y%m%d')
memdf = memdf.rename(columns = {'msno' : 'userid', 'bd': 'age'})
memdf.describe()
# Out:
#                                               userid  city  age  gender  \
# 0       Rb9UwLQTrxzBVwCB6+bCcSQWZ9JiNLC9dXtM1oEsZA8=     1    0     NaN
# 1       +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1    0     NaN
# 2       cV358ssn7a0f7jZOwGNWS07wCKVqxyiImJUX6xcIwKw=     1    0     NaN
# 3       9bzDeJP6sQodK73K5CBlJ6fgIQzPeLnRl0p5B77XP+g=     1    0     NaN
# 4       WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=     6   32  female
# ...                                              ...   ...  ...     ...
# 999995  pyH4hpnklAcIsoQyRsWQB2DVrkTdJG4Guo6UIrafkiI=     8   23  female
# 999996  xPvlcQcuSoUdKtHonU3RQxyUtR/k9WEcYioh1WS/xoc=     1    0     NaN
# 999997  9Gp8Fn5nbSCKmZJ6OEOisXxlKYwBYr6YFjSvxZxWBUw=     1    0     NaN
# 999998  2yVbg0K4+hfNImaKz+//sgZMO7IUo6cfe/U1VUPhdAg=     1    0     NaN
# 999999  lOARWg0mtRanNAnsH9/tYD6gGWLNalQ53AfQN+4y0QM=     1    0     NaN
#
#         registered_via registration_init_time
# 0                   11             2011-09-11
# 1                    7             2011-09-14
# 2                   11             2011-09-15
# 3                   11             2011-09-15
# 4                    9             2011-09-15
# ...                ...                    ...
# 999995               4             2016-01-18
# 999996               7             2016-01-18
# 999997               4             2016-01-18
# 999998               4             2016-01-18
# 999999               9             2016-01-18
#
# [1000000 rows x 6 columns]

# %%
# a lot of null values for gender
memdf.isnull().sum()
# Out:
# userid                         0
# city                           0
# age                            0
# gender                    607944
# registered_via                 0
# registration_init_time         0
# dtype: int64

# %%
# outliers for age (min and max values are way off)

memdf[memdf.age < 0]
# Out:
#                                               userid  city  age  gender  \
# 4268    eY+UDYaAlACNn21sfSJ2qWdwqkRkOwjUvrzuhFdQy74=    12  -39  female
# 61151   vNkNJQDBw9InczAp8FYSMjNEOJ0U9oSOXlaXoYOFm3Q=     1 -518    male
# 62806   T3AH9ITIJQR8ww0WoahoWqb3LYTtt3bs+MylUHTPG5s=    22  -51     NaN
# 135945  GPlFUWdUlP8FsTkHX/vP0DPC/gVxeUR0Ud1D+m7Ohpo=     1 -506    male
# 147468  tirJpLJooXkMQEPHHm98m+uk89BX//aMQRY7yxU3ur8=     1 -510  female
# 147744  bSit4QBkFqZn5jXeFBTqUK7+NmEHTf9giy26K5o7c3k=    13  -36     NaN
# 176270  HQ+YhQ0vouICUSrmnc8OeSetEv5s2YDzkZ7N+Q4V/hw=     5  -43     NaN
# 193759  nOpjmG5Mqizm7z6tApDKi29/X+My10kG/JnssGCq6hc=    13 -958  female
# 254050  8lU9EDGQYba5eZo+vxG38TGEtDSDcJW78QN2JStDgEE=    13  -48     NaN
# 279949  fspqYjHPLxu+wGdC0x8wrS01W63DcjtlgwdrvfxJpbY=    15  -43     NaN
# 283370  W6/ELfYIriE4+H73dVKGNPr0o4NZcN5NYumBj0rVUcQ=    15  -43     NaN
# 296019  Q48xXbdxP7w2dmneRRnbEsNIOCEK4YxuMeGg6wLqJbg=     1 -515  female
# 328131  k115OCbsul6Os5rYosKrGWhwfpsxAo0GJyF7qo7OZPA=    15  -43     NaN
# 351784  iPLpRE33H+WZOpSN0MCZxMLtKigWLRAORpcAHk9/tVw=     1 -504  female
# 354415  8JXMPCsbvYjI/Jcq3+reMMybiFwt0nkJzzU1NKvOUc4=     1 -519  female
# 376212  Fm0ZPqLLmf6a0rkWOKQn/60Vz0vA+UqR2MJR5Gb5bRs=     6  -47     NaN
# 406489  pbwQUaAv8Sj1Uo3uHxtySpoi4zxf0O6MFOh1hJ6rH0I=    13  -42     NaN
# 422293  Jzt1cuxorULR7VG73BFXIPqV24H5KbMqk8AoJnSegFM=    15  -49     NaN
# 439222  fajm2edZua/PxCHFRIcqCbA7GRT0jl4kxKrjvIHfJng=     1 -514    male
# 455039  2yH5KHoM1DFJ1j5a7w+r0XsP8GlkieEbeUWwxI6uf5c=     1 -518    male
# 472900  MsPRVFN+yfWsEl+5lE33jzM07snoTQVBlZcSDfkKTeg=     1 -523    male
# 473130  m6LAcf/eiX5vzdpuh33pxwsKLAaUnMUkjXUUWUe1Khw=     1 -517  female
# 486808  dIpPBhPHPx+s0ClICQndwojc18upZxIPyCo0kEz0e2Y=     1 -510    male
# 488392  ki2yiBqP5N1z+JYK7lN/me4/VBqlLWL1ZkXw/GlhNkk=    18  -49  female
# 494071  2HlAF5zRq8fV+0Mp7UvuNjkf7QyXN2p+KfpODWoRcqQ=     1 -482  female
# 499204  IWlQndzsZ0s8Ux1/O63wID7S4+DO9T+kl6bbRUcQknk=     1 -520  female
# 562288  b3BiwP11AId12YpXNxdQ2+Zka+G38tNCvk1KiXHwk9o=     1 -519    male
# 564758  HFBBqocC+6wvGIQseRHByJCUE9wrubAU2Fm8db3RfyU=     9  -51     NaN
# 635039  NQAe+RML45MZB4GkxzHpwezH9eYY3XBdv9ImuXBbW18=     1 -508    male
# 665944  jUqWrVCoN8hmVUbxpVZC0ntKGe9MGjfghF685gi7VMU=    15 -974  female
# 672654  fHMVKnZEpjJd+5bBBiBmCyZX23KsCLBurSxTTFaD6Fs=    15  -42     NaN
# 711398  PaCrQ5+uc2vY0LTlqjHyA56CpdlggH8zbnkBnC3NIoQ=    13  -37     NaN
# 712403  Rr+uFQlhRlcDL81t1QUD1OfxGawZ6dwZ0qwUzmNsHAQ=     1 -500    male
# 717302  3/0LtPxC8xZElIrmWc4bn/gXaeWP8NQhU5mPPd4krco=     1 -517  female
# 719133  X8gPw4oU02yKokf/dtSSZbfaAvZsEffS41imIqvvjvY=     1 -509  female
# 778363  saLbv4W1hh6RluqG0f+fWDGNGF5+ZJbHi40LhVybatU=     1 -516  female
# 788668  EpnuDGAPB1J5MnUve8ycOXYWdDMcQ4+XRXlF1bC+OEg=     1 -519    male
# 832865  eYFTp6FXwt8Jl4W6uYHaX6x0DRK/dEwokSHjjFckJj4=    13  -46     NaN
# 895532  CCIp7BjEkv3alO1jaXSa6fuxAc6mEet+xpio1fSEipA=     9  -12     NaN
# 997276  dnIt+eTsUToLgHkxTCCrKz4mUmXsfpqPdofUZYtDTlc=    13  -49     NaN
#
#         registered_via registration_init_time
# 4268                 7             2011-04-23
# 61151                4             2016-12-16
# 62806                9             2015-03-20
# 135945               3             2014-06-14
# 147468               9             2014-11-05
# 147744               9             2014-11-23
# 176270               9             2012-04-20
# 193759               9             2014-04-26
# 254050               9             2015-02-17
# 279949               9             2015-04-05
# 283370               9             2015-02-17
# 296019               9             2014-02-26
# 328131               9             2010-11-23
# 351784               3             2014-07-25
# 354415               3             2014-06-16
# 376212               9             2015-04-11
# 406489               9             2015-05-24
# 422293               9             2015-03-10
# 439222               3             2014-06-04
# 455039               9             2014-06-18
# 472900               4             2016-11-30
# 473130               9             2016-12-09
# 486808               2             2014-11-11
# 488392               3             2014-09-07
# 494071               3             2014-05-09
# 499204               9             2015-04-05
# 562288               9             2014-06-17
# 564758               3             2013-01-02
# 635039               3             2014-08-03
# 665944               4             2017-02-25
# 672654               9             2014-07-03
# 711398               9             2015-04-12
# 712403               4             2016-10-29
# 717302               9             2014-05-24
# 719133               9             2014-09-28
# 778363               9             2014-05-08
# 788668               3             2014-05-31
# 832865               3             2013-03-23
# 895532               9             2015-05-27
# 997276               9             2014-12-11

# %%
# join traindf and memdf, resulting rows = traindf total rows, so no rows were dropped during the join.

df1 = traindf.merge(memdf, on = 'msno', how = 'inner')

# %%
df1
# Out:
#                                                 msno  is_churn  city  bd  \
# 0       ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         1     5  28
# 1       f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1    13  20
# 2       zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1    13  18
# 3       8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1     1   0
# 4       K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1    13  35
# ...                                              ...       ...   ...  ..
# 860962  /QlhSIWEZelYnwttYJSQL50EJJ2yRV+ThQIVQLvctp8=         0     8  25
# 860963  OHnZbu+EVaP+vN7Z+OfT5OMcp90MWFZonmM0o3pb8FY=         0    13  28
# 860964  S92bDK//uI6hk3u1vuApro0qJBQOToBozZ7lL1yTC+w=         0     1   0
# 860965  eUa3xo16vpAjr43Cjlb6Kjf1NTILYyJIkBayJQdXWnw=         0     1   0
# 860966  iZE41tbAQ65rJq60olkJT4BJzuUAYgQdfbEemXe/TTk=         0     5  25
#
#         gender  registered_via  registration_init_time
# 0         male               3                20131223
# 1         male               3                20131223
# 2         male               3                20131227
# 3          NaN               7                20140109
# 4       female               7                20140125
# ...        ...             ...                     ...
# 860962  female               7                20110830
# 860963    male               7                20110831
# 860964     NaN               7                20110903
# 860965     NaN               7                20110905
# 860966  female               9                20110905
#
# [860967 rows x 7 columns]

# %%
df1.msno.duplicated().any()
# Out:
# False

# %%
# join df1 with memdf. There are more rows because there are duplciated user ids in userdf 

df2 = df1.merge(transdf, on = 'msno', how = 'inner')

# %%
df2[df2['msno'] == '72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=']
# Out:
#                                                 msno  is_churn  city    bd  \
# 686065  72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=         1   4.0  42.0
# 686066  72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=         1   4.0  42.0
# 686067  72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=         1   4.0  42.0
# 686068  72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=         1   4.0  42.0
# 686069  72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=         1   4.0  42.0
# ...                                              ...       ...   ...   ...
# 686268  72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=         1   4.0  42.0
# 686269  72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=         1   4.0  42.0
# 686270  72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=         1   4.0  42.0
# 686271  72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=         1   4.0  42.0
# 686272  72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=         1   4.0  42.0
#
#        gender  registered_via  registration_init_time  payment_method_id  \
# 686065   male             9.0              20070417.0                 38
# 686066   male             9.0              20070417.0                 38
# 686067   male             9.0              20070417.0                 38
# 686068   male             9.0              20070417.0                 38
# 686069   male             9.0              20070417.0                 38
# ...       ...             ...                     ...                ...
# 686268   male             9.0              20070417.0                 38
# 686269   male             9.0              20070417.0                 38
# 686270   male             9.0              20070417.0                 38
# 686271   male             9.0              20070417.0                 38
# 686272   male             9.0              20070417.0                 38
#
#         payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 686065                  7                0                   0              0
# 686066                  7                0                   0              0
# 686067                  7                0                   0              0
# 686068                  7                0                   0              0
# 686069                  7                0                   0              0
# ...                   ...              ...                 ...            ...
# 686268                  7                0                   0              0
# 686269                  7                0                   0              0
# 686270                  7                0                   0              0
# 686271                  7                0                   0              0
# 686272                  7                0                   0              0
#
#         transaction_date  membership_expire_date  is_cancel
# 686065          20160731                20201125          0
# 686066          20160720                20180103          0
# 686067          20160721                20191030          0
# 686068          20160720                20170816          0
# 686069          20160720                20171213          0
# ...                  ...                     ...        ...
# 686268          20160731                20210317          0
# 686269          20160720                20170913          0
# 686270          20160721                20190522          0
# 686271          20160721                20190508          0
# 686272          20160720                20181107          0
#
# [208 rows x 15 columns]

# %%
df2duplicate = df2[df2.msno.duplicated()]
df2duplicate.msno.value_counts()
# Out:
# 72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=    207
# 5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=    171
# OGKDrZQDB3yewZhoSd5qqvmG5A1GcNTYMexO95NlH+g=    147
# WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=    144
# SNlFRAsmUqnXKPofSXA8WYUc5DtmLcUMy4pXSJ3Ohz0=    130
#                                                ...
# +2xg76nc+yZl09yOjsfBl3UMUKO8ZCBF+e+rrO5SEW8=      1
# 49g/mQkTO8oyoQLidlPZ/oiBdCzW2VwAC4KE0i0VxJI=      1
# O8vrhAt96I/UQupDLzEGRZfZrYiPaSMG0McyrdDH1OI=      1
# ydM9PfwTeOyX+AHB+kK52o7kM0pKkvL1JF0paWUoR60=      1
# iZE41tbAQ65rJq60olkJT4BJzuUAYgQdfbEemXe/TTk=      1
# Name: msno, Length: 115989, dtype: int64

# %%
# Out:
# True
